# %%
# %%capture

# !pip install snowflake-connector-python
# !pip install "snowflake-connector-python[secure-local-storage,pandas]"

# %%
# %%capture

# !pip install snowflake-sqlalchemy

# %%
# %%capture

# !pip install xgboost

# %%
! pip install pandas=="2.1.4"
# Out:
# Collecting pandas==2.1.4
#   Downloading pandas-2.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: numpy<2,>=1.22.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas==2.1.4) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas==2.1.4) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas==2.1.4) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas==2.1.4) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas==2.1.4) (1.16.0)
# Downloading pandas-2.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 23.0 MB/s eta 0:00:0000:010:01
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.1
#     Uninstalling pandas-2.2.1:
#       Successfully uninstalled pandas-2.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# autovizwidget 0.21.0 requires pandas<2.0.0,>=0.20.1, but you have pandas 2.1.4 which is incompatible.
# hdijupyterutils 0.21.0 requires pandas<2.0.0,>=0.17.1, but you have pandas 2.1.4 which is incompatible.
# sparkmagic 0.21.0 requires pandas<2.0.0,>=0.17.1, but you have pandas 2.1.4 which is incompatible.
# Successfully installed pandas-2.1.4

# %%
import os
import pickle
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn import metrics

import sqlalchemy
import snowflake.connector
from sqlalchemy import create_engine
from snowflake.sqlalchemy import *

import xgboost
from datetime import datetime, timedelta
import time  
import pytz    
tz_NY = pytz.timezone('America/Indianapolis')

import snowflake_creds
import LOS_Preprocessing
from LOS_Preprocessing import preprocess_data

import warnings
warnings.filterwarnings('ignore')

# %%
pd.__version__
# Out:
# '2.1.4'

# %%
# Creating the connection engine 
engine = create_engine(URL(
         account = "kbxyguy-yh77168",
        #account="by44730.us-east-2.aws",
        user= snowflake_creds.USER_NAME,
        password= snowflake_creds.PASSWORD,
        role="ACCOUNTADMIN",
        warehouse="COMPUTE_WH",
        database="HEALTHDB",
        schema="PUBLIC"
    ))

# %%
query = """

WITH BASE AS (

    SELECT CASE_ID,
           COALESCE(HOSPITAL_CODE,0) AS HOSPITAL_CODE,
           COALESCE(HOSPITAL_TYPE_CODE,'None') AS HOSPITAL_TYPE_CODE,
           COALESCE(CITY_CODE_HOSPITAL,0) AS CITY_CODE_HOSPITAL,
           COALESCE(HOSPITAL_REGION_CODE,'None') AS HOSPITAL_REGION_CODE,
           COALESCE(AVAILABLE_EXTRA_ROOMS_IN_HOSPITAL,0) AS AVAILABLE_EXTRA_ROOMS_IN_HOSPITAL,
           COALESCE(DEPARTMENT,'None') AS DEPARTMENT,
           COALESCE(WARD_TYPE,'None') AS WARD_TYPE,
           COALESCE(WARD_FACILITY_CODE,'None') AS WARD_FACILITY_CODE,
           COALESCE(BED_GRADE,0) AS BED_GRADE,
           PATIENTID,
           COALESCE(CITY_CODE_PATIENT,0) AS CITY_CODE_PATIENT,
           COALESCE(TYPE_OF_ADMISSION,'None') AS TYPE_OF_ADMISSION,
           COALESCE(SEVERITY_OF_ILLNESS,'Minor') AS SEVERITY_OF_ILLNESS,
           COALESCE(VISITORS_WITH_PATIENT,0) AS VISITORS_WITH_PATIENT,
           COALESCE(AGE,'None') AS AGE,
           COALESCE(ADMISSION_DEPOSIT,0) AS ADMISSION_DEPOSIT,
           ADMISSION_DATE,
           DISCHARGE_DATE

    FROM HEALTHDB.PUBLIC.SIMULATION_DATA

),
    
BASE_WITH_FEATURES AS (

    SELECT *,
            MONTHNAME(ADMISSION_DATE) AS ADMISSION_MONTH,
            DAYNAME(ADMISSION_DATE) AS ADMISSION_DAY,
            CONCAT(TYPE_OF_ADMISSION,'-',SEVERITY_OF_ILLNESS) AS ADMISSION_ILLNESS,
            CONCAT(SEVERITY_OF_ILLNESS,'-',BED_GRADE) AS ILLNESS_BEDGRADE,
            CONCAT(DEPARTMENT,'-',SEVERITY_OF_ILLNESS) AS DEPARTMENT_ILLNESS,
            DATEDIFF(day,ADMISSION_DATE,DISCHARGE_DATE) AS LOS
    FROM BASE 

)    

SELECT * FROM BASE_WITH_FEATURES WHERE ADMISSION_DATE = CURRENT_DATE-542
"""

# %%
# To test if the data is being inserted to the snowflake database
def check_n_create_model_features(df,feat_list):
    test = pd.DataFrame()
    for col in feat_list:
        if col in df.columns.tolist():
            test[col] = df[col]
        else:
            test[col] = 0
    
    return test



def insert_predictions_to_snowflake_table(data):
    import pandas
    import snowflake.connector
    from snowflake.connector.pandas_tools import pd_writer, write_pandas

    engine = create_engine(URL(
             account = "kbxyguy-yh77168",
        #account="by44730.us-east-2.aws",
        user= snowflake_creds.USER_NAME,
        password= snowflake_creds.PASSWORD,
        role="ACCOUNTADMIN",
        warehouse="COMPUTE_WH",
        database="HEALTHDB",
        schema="PUBLIC"
        ))  
    
    # Creating the logging table if not exists already
    table = 'TEMP_LOS_PREDICTION_MODEL_LOGGING_TABLE'
    
    # Inserting the data to snowflake logging table
    data.to_sql(table, engine, index=False, if_exists='append', method=pd_writer)
    return 'Success'

# %%
with engine.connect() as conn:
    
    # Loading the scoring data
    score_data = pd.DataFrame(pd.read_sql(query,con = conn))
    score_data.columns = [col.upper() for col in score_data.columns.tolist()]
    
    # Applying the preprocessing steps
    score_data_processed = LOS_Preprocessing.preprocess_data(score_data)
    
    # Applying feature selection
    final_feats = pd.read_pickle('MODEL_FEATS.pkl')
    score_data_final = check_n_create_model_features(score_data_processed,final_feats)
    
    # Getting the predictions
    model = xgboost.XGBRegressor()
    model.load_model('MODEL_XGB.model')
    score_data_final['PREDICTED_LOS'] = np.ceil(model.predict(score_data_final.drop('LOS',axis=1)))
    
    # Writing the dataframe to snowflake as a table
    score_data_final = score_data_final.reset_index()
    score_data_table = pd.merge(score_data,score_data_final,on='CASE_ID',how='left')
    #status = insert_predictions_to_snowflake_table(score_data_table)

# %%
print(score_data.shape)
score_data.head()
# Out:
# (2362, 25)
#    CASE_ID  HOSPITAL_CODE HOSPITAL_TYPE_CODE  CITY_CODE_HOSPITAL  \
# 0     2363             18                  d                  13
# 1     2364             28                  b                  11
# 2     2365             11                  b                   2
# 3     2366             23                  a                   6
# 4     2367              2                  c                   5
#
#   HOSPITAL_REGION_CODE  AVAILABLE_EXTRA_ROOMS_IN_HOSPITAL    DEPARTMENT  \
# 0                    Y                                  4  radiotherapy
# 1                    X                                  3    anesthesia
# 2                    Y                                  4    gynecology
# 3                    X                                  4    gynecology
# 4                    Z                                  4    gynecology
#
#   WARD_TYPE WARD_FACILITY_CODE  BED_GRADE  PATIENTID  CITY_CODE_PATIENT  \
# 0         Q                  B          2     127970                  3
# 1         R                  F          3      74756                  5
# 2         Q                  D          4      53888                  5
# 3         Q                  F          1     107753                  2
# 4         S                  F          2     107506                  9
#
#   TYPE_OF_ADMISSION SEVERITY_OF_ILLNESS  VISITORS_WITH_PATIENT     AGE  \
# 0            Trauma            Moderate                      5   31-40
# 1            Trauma             Extreme                      2  20-Nov
# 2         Emergency               Minor                      2   41-50
# 3            Trauma             Extreme                      2   51-60
# 4         Emergency             Extreme                      2   51-60
#
#    ADMISSION_DEPOSIT ADMISSION_DATE DISCHARGE_DATE ADMISSION_MONTH  \
# 0               3778     2022-12-02     2023-01-21             Dec
# 1               4710     2022-12-02     2022-12-22             Dec
# 2               7073     2022-12-02     2023-01-11             Dec
# 3               6203     2022-12-02     2023-01-01             Dec
# 4               3583     2022-12-02     2022-12-22             Dec
#
#   ADMISSION_DAY  ADMISSION_ILLNESS ILLNESS_BEDGRADE     DEPARTMENT_ILLNESS  \
# 0           Fri    Trauma-Moderate       Moderate-2  radiotherapy-Moderate
# 1           Fri     Trauma-Extreme        Extreme-3     anesthesia-Extreme
# 2           Fri    Emergency-Minor          Minor-4       gynecology-Minor
# 3           Fri     Trauma-Extreme        Extreme-1     gynecology-Extreme
# 4           Fri  Emergency-Extreme        Extreme-2     gynecology-Extreme
#
#    LOS
# 0   50
# 1   20
# 2   40
# 3   30
# 4   20

# %%
print(score_data_processed.shape)
score_data_processed.head()
# Out:
# (2362, 128)
#          AVAILABLE_EXTRA_ROOMS_IN_HOSPITAL  VISITORS_WITH_PATIENT  \
# CASE_ID
# 2363                                     4                      5
# 2364                                     3                      2
# 2365                                     4                      2
# 2366                                     4                      2
# 2367                                     4                      2
#
#          ADMISSION_DEPOSIT  LOS  HOSPITAL_TYPE_CODE_a  HOSPITAL_TYPE_CODE_b  \
# CASE_ID
# 2363                  3778   50                 False                 False
# 2364                  4710   20                 False                  True
# 2365                  7073   40                 False                  True
# 2366                  6203   30                  True                 False
# 2367                  3583   20                 False                 False
#
#          HOSPITAL_TYPE_CODE_c  HOSPITAL_TYPE_CODE_d  HOSPITAL_TYPE_CODE_e  \
# CASE_ID
# 2363                    False                  True                 False
# 2364                    False                 False                 False
# 2365                    False                 False                 False
# 2366                    False                 False                 False
# 2367                     True                 False                 False
#
#          HOSPITAL_TYPE_CODE_f  HOSPITAL_TYPE_CODE_g  CITY_CODE_HOSPITAL_1  \
# CASE_ID
# 2363                    False                 False                 False
# 2364                    False                 False                 False
# 2365                    False                 False                 False
# 2366                    False                 False                 False
# 2367                    False                 False                 False
#
#          CITY_CODE_HOSPITAL_2  CITY_CODE_HOSPITAL_3  CITY_CODE_HOSPITAL_4  \
# CASE_ID
# 2363                    False                 False                 False
# 2364                    False                 False                 False
# 2365                     True                 False                 False
# 2366                    False                 False                 False
# 2367                    False                 False                 False
#
#          CITY_CODE_HOSPITAL_5  CITY_CODE_HOSPITAL_6  CITY_CODE_HOSPITAL_7  \
# CASE_ID
# 2363                    False                 False                 False
# 2364                    False                 False                 False
# 2365                    False                 False                 False
# 2366                    False                  True                 False
# 2367                     True                 False                 False
#
#          CITY_CODE_HOSPITAL_9  CITY_CODE_HOSPITAL_10  CITY_CODE_HOSPITAL_11  \
# CASE_ID
# 2363                    False                  False                  False
# 2364                    False                  False                   True
# 2365                    False                  False                  False
# 2366                    False                  False                  False
# 2367                    False                  False                  False
#
#          CITY_CODE_HOSPITAL_13  HOSPITAL_REGION_CODE_X  \
# CASE_ID
# 2363                      True                   False
# 2364                     False                    True
# 2365                     False                   False
# 2366                     False                    True
# 2367                     False                   False
#
#          HOSPITAL_REGION_CODE_Y  HOSPITAL_REGION_CODE_Z  \
# CASE_ID
# 2363                       True                   False
# 2364                      False                   False
# 2365                       True                   False
# 2366                      False                   False
# 2367                      False                    True
#
#          DEPARTMENT_TB & Chest disease  DEPARTMENT_anesthesia  \
# CASE_ID
# 2363                             False                  False
# 2364                             False                   True
# 2365                             False                  False
# 2366                             False                  False
# 2367                             False                  False
#
#          DEPARTMENT_gynecology  DEPARTMENT_radiotherapy  DEPARTMENT_surgery  \
# CASE_ID
# 2363                     False                     True               False
# 2364                     False                    False               False
# 2365                      True                    False               False
# 2366                      True                    False               False
# 2367                      True                    False               False
#
#          WARD_TYPE_P  WARD_TYPE_Q  WARD_TYPE_R  WARD_TYPE_S  WARD_TYPE_T  \
# CASE_ID
# 2363           False         True        False        False        False
# 2364           False        False         True        False        False
# 2365           False         True        False        False        False
# 2366           False         True        False        False        False
# 2367           False        False        False         True        False
#
#          WARD_FACILITY_CODE_A  WARD_FACILITY_CODE_B  WARD_FACILITY_CODE_C  \
# CASE_ID
# 2363                    False                  True                 False
# 2364                    False                 False                 False
# 2365                    False                 False                 False
# 2366                    False                 False                 False
# 2367                    False                 False                 False
#
#          WARD_FACILITY_CODE_D  WARD_FACILITY_CODE_E  WARD_FACILITY_CODE_F  \
# CASE_ID
# 2363                    False                 False                 False
# 2364                    False                 False                  True
# 2365                     True                 False                 False
# 2366                    False                 False                  True
# 2367                    False                 False                  True
#
#          BED_GRADE_1  BED_GRADE_2  BED_GRADE_3  BED_GRADE_4  \
# CASE_ID
# 2363           False         True        False        False
# 2364           False        False         True        False
# 2365           False        False        False         True
# 2366            True        False        False        False
# 2367           False         True        False        False
#
#          CITY_CODE_PATIENT_0  CITY_CODE_PATIENT_1  CITY_CODE_PATIENT_2  \
# CASE_ID
# 2363                   False                False                False
# 2364                   False                False                False
# 2365                   False                False                False
# 2366                   False                False                 True
# 2367                   False                False                False
#
#          CITY_CODE_PATIENT_3  CITY_CODE_PATIENT_4  CITY_CODE_PATIENT_5  \
# CASE_ID
# 2363                    True                False                False
# 2364                   False                False                 True
# 2365                   False                False                 True
# 2366                   False                False                False
# 2367                   False                False                False
#
#          CITY_CODE_PATIENT_6  CITY_CODE_PATIENT_7  CITY_CODE_PATIENT_8  \
# CASE_ID
# 2363                   False                False                False
# 2364                   False                False                False
# 2365                   False                False                False
# 2366                   False                False                False
# 2367                   False                False                False
#
#          CITY_CODE_PATIENT_9  CITY_CODE_PATIENT_10  CITY_CODE_PATIENT_11  \
# CASE_ID
# 2363                   False                 False                 False
# 2364                   False                 False                 False
# 2365                   False                 False                 False
# 2366                   False                 False                 False
# 2367                    True                 False                 False
#
#          CITY_CODE_PATIENT_12  CITY_CODE_PATIENT_13  CITY_CODE_PATIENT_14  \
# CASE_ID
# 2363                    False                 False                 False
# 2364                    False                 False                 False
# 2365                    False                 False                 False
# 2366                    False                 False                 False
# 2367                    False                 False                 False
#
#          CITY_CODE_PATIENT_15  CITY_CODE_PATIENT_16  CITY_CODE_PATIENT_18  \
# CASE_ID
# 2363                    False                 False                 False
# 2364                    False                 False                 False
# 2365                    False                 False                 False
# 2366                    False                 False                 False
# 2367                    False                 False                 False
#
#          CITY_CODE_PATIENT_19  CITY_CODE_PATIENT_20  CITY_CODE_PATIENT_21  \
# CASE_ID
# 2363                    False                 False                 False
# 2364                    False                 False                 False
# 2365                    False                 False                 False
# 2366                    False                 False                 False
# 2367                    False                 False                 False
#
#          CITY_CODE_PATIENT_22  CITY_CODE_PATIENT_23  CITY_CODE_PATIENT_24  \
# CASE_ID
# 2363                    False                 False                 False
# 2364                    False                 False                 False
# 2365                    False                 False                 False
# 2366                    False                 False                 False
# 2367                    False                 False                 False
#
#          CITY_CODE_PATIENT_25  CITY_CODE_PATIENT_26  CITY_CODE_PATIENT_27  \
# CASE_ID
# 2363                    False                 False                 False
# 2364                    False                 False                 False
# 2365                    False                 False                 False
# 2366                    False                 False                 False
# 2367                    False                 False                 False
#
#          CITY_CODE_PATIENT_28  CITY_CODE_PATIENT_29  CITY_CODE_PATIENT_30  \
# CASE_ID
# 2363                    False                 False                 False
# 2364                    False                 False                 False
# 2365                    False                 False                 False
# 2366                    False                 False                 False
# 2367                    False                 False                 False
#
#          TYPE_OF_ADMISSION_Emergency  TYPE_OF_ADMISSION_Trauma  \
# CASE_ID
# 2363                           False                      True
# 2364                           False                      True
# 2365                            True                     False
# 2366                           False                      True
# 2367                            True                     False
#
#          TYPE_OF_ADMISSION_Urgent  SEVERITY_OF_ILLNESS_Extreme  \
# CASE_ID
# 2363                        False                        False
# 2364                        False                         True
# 2365                        False                        False
# 2366                        False                         True
# 2367                        False                         True
#
#          SEVERITY_OF_ILLNESS_Minor  SEVERITY_OF_ILLNESS_Moderate  AGE_0-10  \
# CASE_ID
# 2363                         False                          True     False
# 2364                         False                         False     False
# 2365                          True                         False     False
# 2366                         False                         False     False
# 2367                         False                         False     False
#
#          AGE_20-Nov  AGE_21-30  AGE_31-40  AGE_41-50  AGE_51-60  AGE_61-70  \
# CASE_ID
# 2363          False      False       True      False      False      False
# 2364           True      False      False      False      False      False
# 2365          False      False      False       True      False      False
# 2366          False      False      False      False       True      False
# 2367          False      False      False      False       True      False
#
#          AGE_71-80  AGE_81-90  AGE_91-100  ADMISSION_MONTH_Dec  \
# CASE_ID
# 2363         False      False       False                 True
# 2364         False      False       False                 True
# 2365         False      False       False                 True
# 2366         False      False       False                 True
# 2367         False      False       False                 True
#
#          ADMISSION_DAY_Fri  ADMISSION_ILLNESS_Emergency-Extreme  \
# CASE_ID
# 2363                  True                                False
# 2364                  True                                False
# 2365                  True                                False
# 2366                  True                                False
# 2367                  True                                 True
#
#          ADMISSION_ILLNESS_Emergency-Minor  \
# CASE_ID
# 2363                                 False
# 2364                                 False
# 2365                                  True
# 2366                                 False
# 2367                                 False
#
#          ADMISSION_ILLNESS_Emergency-Moderate  \
# CASE_ID
# 2363                                    False
# 2364                                    False
# 2365                                    False
# 2366                                    False
# 2367                                    False
#
#          ADMISSION_ILLNESS_Trauma-Extreme  ADMISSION_ILLNESS_Trauma-Minor  \
# CASE_ID
# 2363                                False                           False
# 2364                                 True                           False
# 2365                                False                           False
# 2366                                 True                           False
# 2367                                False                           False
#
#          ADMISSION_ILLNESS_Trauma-Moderate  ADMISSION_ILLNESS_Urgent-Extreme  \
# CASE_ID
# 2363                                  True                             False
# 2364                                 False                             False
# 2365                                 False                             False
# 2366                                 False                             False
# 2367                                 False                             False
#
#          ADMISSION_ILLNESS_Urgent-Minor  ADMISSION_ILLNESS_Urgent-Moderate  \
# CASE_ID
# 2363                              False                              False
# 2364                              False                              False
# 2365                              False                              False
# 2366                              False                              False
# 2367                              False                              False
#
#          ILLNESS_BEDGRADE_Extreme-1  ILLNESS_BEDGRADE_Extreme-2  \
# CASE_ID
# 2363                          False                       False
# 2364                          False                       False
# 2365                          False                       False
# 2366                           True                       False
# 2367                          False                        True
#
#          ILLNESS_BEDGRADE_Extreme-3  ILLNESS_BEDGRADE_Extreme-4  \
# CASE_ID
# 2363                          False                       False
# 2364                           True                       False
# 2365                          False                       False
# 2366                          False                       False
# 2367                          False                       False
#
#          ILLNESS_BEDGRADE_Minor-1  ILLNESS_BEDGRADE_Minor-2  \
# CASE_ID
# 2363                        False                     False
# 2364                        False                     False
# 2365                        False                     False
# 2366                        False                     False
# 2367                        False                     False
#
#          ILLNESS_BEDGRADE_Minor-3  ILLNESS_BEDGRADE_Minor-4  \
# CASE_ID
# 2363                        False                     False
# 2364                        False                     False
# 2365                        False                      True
# 2366                        False                     False
# 2367                        False                     False
#
#          ILLNESS_BEDGRADE_Moderate-1  ILLNESS_BEDGRADE_Moderate-2  \
# CASE_ID
# 2363                           False                         True
# 2364                           False                        False
# 2365                           False                        False
# 2366                           False                        False
# 2367                           False                        False
#
#          ILLNESS_BEDGRADE_Moderate-3  ILLNESS_BEDGRADE_Moderate-4  \
# CASE_ID
# 2363                           False                        False
# 2364                           False                        False
# 2365                           False                        False
# 2366                           False                        False
# 2367                           False                        False
#
#          DEPARTMENT_ILLNESS_TB & Chest disease-Extreme  \
# CASE_ID
# 2363                                             False
# 2364                                             False
# 2365                                             False
# 2366                                             False
# 2367                                             False
#
#          DEPARTMENT_ILLNESS_TB & Chest disease-Minor  \
# CASE_ID
# 2363                                           False
# 2364                                           False
# 2365                                           False
# 2366                                           False
# 2367                                           False
#
#          DEPARTMENT_ILLNESS_TB & Chest disease-Moderate  \
# CASE_ID
# 2363                                              False
# 2364                                              False
# 2365                                              False
# 2366                                              False
# 2367                                              False
#
#          DEPARTMENT_ILLNESS_anesthesia-Extreme  \
# CASE_ID
# 2363                                     False
# 2364                                      True
# 2365                                     False
# 2366                                     False
# 2367                                     False
#
#          DEPARTMENT_ILLNESS_anesthesia-Minor  \
# CASE_ID
# 2363                                   False
# 2364                                   False
# 2365                                   False
# 2366                                   False
# 2367                                   False
#
#          DEPARTMENT_ILLNESS_anesthesia-Moderate  \
# CASE_ID
# 2363                                      False
# 2364                                      False
# 2365                                      False
# 2366                                      False
# 2367                                      False
#
#          DEPARTMENT_ILLNESS_gynecology-Extreme  \
# CASE_ID
# 2363                                     False
# 2364                                     False
# 2365                                     False
# 2366                                      True
# 2367                                      True
#
#          DEPARTMENT_ILLNESS_gynecology-Minor  \
# CASE_ID
# 2363                                   False
# 2364                                   False
# 2365                                    True
# 2366                                   False
# 2367                                   False
#
#          DEPARTMENT_ILLNESS_gynecology-Moderate  \
# CASE_ID
# 2363                                      False
# 2364                                      False
# 2365                                      False
# 2366                                      False
# 2367                                      False
#
#          DEPARTMENT_ILLNESS_radiotherapy-Extreme  \
# CASE_ID
# 2363                                       False
# 2364                                       False
# 2365                                       False
# 2366                                       False
# 2367                                       False
#
#          DEPARTMENT_ILLNESS_radiotherapy-Minor  \
# CASE_ID
# 2363                                     False
# 2364                                     False
# 2365                                     False
# 2366                                     False
# 2367                                     False
#
#          DEPARTMENT_ILLNESS_radiotherapy-Moderate  \
# CASE_ID
# 2363                                         True
# 2364                                        False
# 2365                                        False
# 2366                                        False
# 2367                                        False
#
#          DEPARTMENT_ILLNESS_surgery-Extreme  \
# CASE_ID
# 2363                                  False
# 2364                                  False
# 2365                                  False
# 2366                                  False
# 2367                                  False
#
#          DEPARTMENT_ILLNESS_surgery-Moderate
# CASE_ID
# 2363                                   False
# 2364                                   False
# 2365                                   False
# 2366                                   False
# 2367                                   False

# %%
print(score_data_final.shape)
score_data_final.head()
# Out:
# (2362, 23)
#    CASE_ID  BED_GRADE_2  AVAILABLE_EXTRA_ROOMS_IN_HOSPITAL  \
# 0     2363         True                                  4
# 1     2364        False                                  3
# 2     2365        False                                  4
# 3     2366        False                                  4
# 4     2367         True                                  4
#
#    CITY_CODE_HOSPITAL_2  ADMISSION_MONTH_Nov  AGE_31-40  WARD_TYPE_S  \
# 0                 False                    0       True        False
# 1                 False                    0      False        False
# 2                  True                    0      False        False
# 3                 False                    0      False        False
# 4                 False                    0      False         True
#
#    ADMISSION_DEPOSIT  ILLNESS_BEDGRADE_Extreme-1  WARD_TYPE_P  AGE_71-80  \
# 0               3778                       False        False      False
# 1               4710                       False        False      False
# 2               7073                       False        False      False
# 3               6203                        True        False      False
# 4               3583                       False        False      False
#
#    VISITORS_WITH_PATIENT  AGE_51-60  SEVERITY_OF_ILLNESS_Minor  \
# 0                      5      False                      False
# 1                      2      False                      False
# 2                      2      False                       True
# 3                      2       True                      False
# 4                      2       True                      False
#
#    CITY_CODE_PATIENT_8  CITY_CODE_HOSPITAL_7  TYPE_OF_ADMISSION_Trauma  \
# 0                False                 False                      True
# 1                False                 False                      True
# 2                False                 False                     False
# 3                False                 False                      True
# 4                False                 False                     False
#
#    ADMISSION_MONTH_Oct  AGE_41-50  WARD_TYPE_Q  TYPE_OF_ADMISSION_Emergency  \
# 0                    0      False         True                        False
# 1                    0      False        False                        False
# 2                    0       True         True                         True
# 3                    0      False         True                        False
# 4                    0      False        False                         True
#
#    LOS  PREDICTED_LOS
# 0   50           58.0
# 1   20           28.0
# 2   40           31.0
# 3   30           35.0
# 4   20           28.0

# %%
print(score_data_table.shape)
score_data_table.head()
# Out:
# (2362, 47)
#    CASE_ID  HOSPITAL_CODE HOSPITAL_TYPE_CODE  CITY_CODE_HOSPITAL  \
# 0     2363             18                  d                  13
# 1     2364             28                  b                  11
# 2     2365             11                  b                   2
# 3     2366             23                  a                   6
# 4     2367              2                  c                   5
#
#   HOSPITAL_REGION_CODE  AVAILABLE_EXTRA_ROOMS_IN_HOSPITAL_x    DEPARTMENT  \
# 0                    Y                                    4  radiotherapy
# 1                    X                                    3    anesthesia
# 2                    Y                                    4    gynecology
# 3                    X                                    4    gynecology
# 4                    Z                                    4    gynecology
#
#   WARD_TYPE WARD_FACILITY_CODE  BED_GRADE  PATIENTID  CITY_CODE_PATIENT  \
# 0         Q                  B          2     127970                  3
# 1         R                  F          3      74756                  5
# 2         Q                  D          4      53888                  5
# 3         Q                  F          1     107753                  2
# 4         S                  F          2     107506                  9
#
#   TYPE_OF_ADMISSION SEVERITY_OF_ILLNESS  VISITORS_WITH_PATIENT_x     AGE  \
# 0            Trauma            Moderate                        5   31-40
# 1            Trauma             Extreme                        2  20-Nov
# 2         Emergency               Minor                        2   41-50
# 3            Trauma             Extreme                        2   51-60
# 4         Emergency             Extreme                        2   51-60
#
#    ADMISSION_DEPOSIT_x ADMISSION_DATE DISCHARGE_DATE ADMISSION_MONTH  \
# 0                 3778     2022-12-02     2023-01-21             Dec
# 1                 4710     2022-12-02     2022-12-22             Dec
# 2                 7073     2022-12-02     2023-01-11             Dec
# 3                 6203     2022-12-02     2023-01-01             Dec
# 4                 3583     2022-12-02     2022-12-22             Dec
#
#   ADMISSION_DAY  ADMISSION_ILLNESS ILLNESS_BEDGRADE     DEPARTMENT_ILLNESS  \
# 0           Fri    Trauma-Moderate       Moderate-2  radiotherapy-Moderate
# 1           Fri     Trauma-Extreme        Extreme-3     anesthesia-Extreme
# 2           Fri    Emergency-Minor          Minor-4       gynecology-Minor
# 3           Fri     Trauma-Extreme        Extreme-1     gynecology-Extreme
# 4           Fri  Emergency-Extreme        Extreme-2     gynecology-Extreme
#
#    LOS_x  BED_GRADE_2  AVAILABLE_EXTRA_ROOMS_IN_HOSPITAL_y  \
# 0     50         True                                    4
# 1     20        False                                    3
# 2     40        False                                    4
# 3     30        False                                    4
# 4     20         True                                    4
#
#    CITY_CODE_HOSPITAL_2  ADMISSION_MONTH_Nov  AGE_31-40  WARD_TYPE_S  \
# 0                 False                    0       True        False
# 1                 False                    0      False        False
# 2                  True                    0      False        False
# 3                 False                    0      False        False
# 4                 False                    0      False         True
#
#    ADMISSION_DEPOSIT_y  ILLNESS_BEDGRADE_Extreme-1  WARD_TYPE_P  AGE_71-80  \
# 0                 3778                       False        False      False
# 1                 4710                       False        False      False
# 2                 7073                       False        False      False
# 3                 6203                        True        False      False
# 4                 3583                       False        False      False
#
#    VISITORS_WITH_PATIENT_y  AGE_51-60  SEVERITY_OF_ILLNESS_Minor  \
# 0                        5      False                      False
# 1                        2      False                      False
# 2                        2      False                       True
# 3                        2       True                      False
# 4                        2       True                      False
#
#    CITY_CODE_PATIENT_8  CITY_CODE_HOSPITAL_7  TYPE_OF_ADMISSION_Trauma  \
# 0                False                 False                      True
# 1                False                 False                      True
# 2                False                 False                     False
# 3                False                 False                      True
# 4                False                 False                     False
#
#    ADMISSION_MONTH_Oct  AGE_41-50  WARD_TYPE_Q  TYPE_OF_ADMISSION_Emergency  \
# 0                    0      False         True                        False
# 1                    0      False        False                        False
# 2                    0       True         True                         True
# 3                    0      False         True                        False
# 4                    0      False        False                         True
#
#    LOS_y  PREDICTED_LOS
# 0     50           58.0
# 1     20           28.0
# 2     40           31.0
# 3     30           35.0
# 4     20           28.0

# %% [markdown]
# # Scoring Function for Deployment:

# %%
query = """

WITH BASE AS (

    SELECT CASE_ID,
           COALESCE(HOSPITAL_CODE,0) AS HOSPITAL_CODE,
           COALESCE(HOSPITAL_TYPE_CODE,'None') AS HOSPITAL_TYPE_CODE,
           COALESCE(CITY_CODE_HOSPITAL,0) AS CITY_CODE_HOSPITAL,
           COALESCE(HOSPITAL_REGION_CODE,'None') AS HOSPITAL_REGION_CODE,
           COALESCE(AVAILABLE_EXTRA_ROOMS_IN_HOSPITAL,0) AS AVAILABLE_EXTRA_ROOMS_IN_HOSPITAL,
           COALESCE(DEPARTMENT,'None') AS DEPARTMENT,
           COALESCE(WARD_TYPE,'None') AS WARD_TYPE,
           COALESCE(WARD_FACILITY_CODE,'None') AS WARD_FACILITY_CODE,
           COALESCE(BED_GRADE,0) AS BED_GRADE,
           PATIENTID,
           COALESCE(CITY_CODE_PATIENT,0) AS CITY_CODE_PATIENT,
           COALESCE(TYPE_OF_ADMISSION,'None') AS TYPE_OF_ADMISSION,
           COALESCE(SEVERITY_OF_ILLNESS,'Minor') AS SEVERITY_OF_ILLNESS,
           COALESCE(VISITORS_WITH_PATIENT,0) AS VISITORS_WITH_PATIENT,
           COALESCE(AGE,'None') AS AGE,
           COALESCE(ADMISSION_DEPOSIT,0) AS ADMISSION_DEPOSIT,
           ADMISSION_DATE,
           DISCHARGE_DATE

    FROM HEALTHDB.PUBLIC.SIMULATION_DATA

),
    
BASE_WITH_FEATURES AS (

    SELECT *,
            MONTHNAME(ADMISSION_DATE) AS ADMISSION_MONTH,
            DAYNAME(ADMISSION_DATE) AS ADMISSION_DAY,
            CONCAT(TYPE_OF_ADMISSION,'-',SEVERITY_OF_ILLNESS) AS ADMISSION_ILLNESS,
            CONCAT(SEVERITY_OF_ILLNESS,'-',BED_GRADE) AS ILLNESS_BEDGRADE,
            CONCAT(DEPARTMENT,'-',SEVERITY_OF_ILLNESS) AS DEPARTMENT_ILLNESS,
            DATEDIFF(day,ADMISSION_DATE,DISCHARGE_DATE) AS LOS
    FROM BASE 

)    

SELECT * FROM BASE_WITH_FEATURES WHERE ADMISSION_DATE = CURRENT_DATE-543
"""

# %%
def check_n_create_model_features(df,feat_list):
    test = pd.DataFrame()
    for col in feat_list:
        if col in df.columns.tolist():
            test[col] = df[col]
        else:
            test[col] = 0
    
    return test


def insert_predictions_to_snowflake_table(data):
    import pandas
    import snowflake.connector
    from snowflake.connector.pandas_tools import pd_writer, write_pandas

    engine = create_engine(URL(
            account = "kbxyguy-yh77168",
        #account="by44730.us-east-2.aws",
        user= snowflake_creds.USER_NAME,
        password= snowflake_creds.PASSWORD,
        role="ACCOUNTADMIN",
        warehouse="COMPUTE_WH",
        database="HEALTHDB",
        schema="PUBLIC"
        ))  
    
    # Creating the logging table if not exists already
    table = 'TEMP_LOS_PREDICTION_MODEL_LOGGING_TABLE_EMAIL_MONITORED'
    
    # Inserting the data to snowflake logging table
    data.to_sql(table, engine, index=False, if_exists='append', method=pd_writer)
    return 'Success'

# %%
def send_status_mail(mail_string):
    import mail_creds
    import smtplib
    from email.mime.multipart import MIMEMultipart
    from email.mime.text import MIMEText
    from email.mime.multipart import MIMEMultipart
    from email.mime.base import MIMEBase
    from email.mime.text import MIMEText
    from email.utils import formatdate
    from email import encoders
    
    subject = 'Patient LOS Prediction - STATUS MAIL'
    mail_content = mail_string

    username= mail_creds.MAIL_ID
    password= mail_creds.APP_PASSWORD
    send_from = mail_creds.MAIL_ID
    send_to = mail_creds.MAIL_ID
    Cc = ''
    msg = MIMEMultipart()
    msg['From'] = send_from
    msg['To'] = send_to
    msg['Cc'] = Cc
    msg['Date'] = formatdate(localtime = True)
    msg['Subject'] = subject
    msg.attach(MIMEText(mail_content, 'plain'))
    smtp = smtplib.SMTP('smtp.gmail.com',587)
    smtp.ehlo()
    smtp.starttls()
    smtp.login(username,password)
    smtp.sendmail(send_from, send_to.split(',') + msg['Cc'].split(','), msg.as_string())
    smtp.quit()

# %%
def LOS_MODEL_DEPLOYMENT():
    try:
        import pickle
        import pandas as pd
        import numpy as np
        import sqlalchemy
        import snowflake.connector
        from sqlalchemy import create_engine

        import xgboost as xgb
        from datetime import datetime, timedelta
        import time  
        import pytz    
        tz_NY = pytz.timezone('America/Indianapolis')

        import warnings
        warnings.filterwarnings('ignore')   
        
        import snowflake_creds
        import LOS_Preprocessing
        from LOS_Preprocessing import preprocess_data
        
        # Creating the connection engine
        engine = create_engine(URL(
                account = "kbxyguy-yh77168",
        user= snowflake_creds.USER_NAME,
        password= snowflake_creds.PASSWORD,
        role="ACCOUNTADMIN",
        warehouse="COMPUTE_WH",
        database="HEALTHDB",
        schema="PUBLIC"
            ))
        
        mail_list = []
        
        with engine.connect() as conn:
    
            # Loading the scoring data
            score_data = pd.DataFrame(pd.read_sql(query,conn))
            score_data.columns = [col.upper() for col in score_data.columns.tolist()]
            mail_list.append('STEP-1: Loading Data complete')

            # Applying the preprocessing steps
            score_data_processed = LOS_Preprocessing.preprocess_data(score_data)
            mail_list.append('STEP-2: Applying the Preprocessing Steps complete')

            # Applying feature selection
            final_feats = pd.read_pickle('MODEL_FEATS.pkl')
            score_data_final = check_n_create_model_features(score_data_processed,final_feats)
            mail_list.append('STEP-3: Applying the Feature Selection Steps complete')

            # Getting the predictions
            model = xgboost.XGBRegressor()
            model.load_model('MODEL_XGB.model')
            score_data_final['PREDICTED_LOS'] = np.ceil(model.predict(score_data_final.drop('LOS',axis=1)))
            mail_list.append('STEP-4: Getting the Predictions complete')

            # Writing the dataframe to snowflake as a table
            score_data_final = score_data_final.reset_index()
            score_data_table = pd.merge(score_data,score_data_final,on='CASE_ID',how='left')
            status = insert_predictions_to_snowflake_table(score_data_table)
            mail_list.append('STEP-5: Writing the data to snowflake complete')
            
            # Creating the mail body
            mail_string = ",\n ".join(map(str, mail_list))
            send_status_mail(mail_string)
            print('Success')
    
    except:
        
        mail_content = 'Schedule is failed'
        send_status_mail(mail_content)
        print('Failed')

# %%
LOS_MODEL_DEPLOYMENT()
# Out:
# Success

# %%
# Scheduling the notebook

import time
from datetime import datetime    
import pytz    
tz_NY = pytz.timezone('America/Indianapolis')   
 

# scheduled hours in 24-hour format
hours_list = ["18:29"]
 
while True:
    tz_NY = pytz.timezone('America/Indianapolis')   
    now = datetime.now(tz_NY)  # gets current datetime

    hour = str(now.hour) # gets current hour
    minute = str(now.minute) # gets current minute
    current_time = f"{hour}:{minute}" # combines current hour and minute

    # checks if current time is in the hours list
    if current_time in hours_list:
        LOS_MODEL_DEPLOYMENT()
    
    time.sleep(60) # waits a minute until it repeats
# Out:
# Success
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 24
#      21 if current_time in hours_list:
#      22     LOS_MODEL_DEPLOYMENT()
# ---> 24 time.sleep(60) # waits a minute until it repeats
#
# KeyboardInterrupt:

# %%
print(datetime.now())
# Out:
# 2024-05-27 22:30:52.203873

# %%
tz_NY = pytz.timezone('America/Indianapolis') 
print(datetime.now(tz_NY))
# Out:
# 2024-05-27 18:31:05.653112-04:00

# %% [markdown]
# Till above, the implementation of storing the data to the Snowflake and setting up a notebook instance which runs on a specific time is successfull. However, for the simulation purpose we will try ti generate the prediction at one one for 30 days present in the data from "2022-12-1" to "2022-12-31" using a loop which runs once and we get the data stored in the snowflake.

# %% [markdown]
# # Live Data Scoring Simulation:

# %%
engine = create_engine(URL(
                account = "kbxyguy-yh77168",
        user= snowflake_creds.USER_NAME,
        password= snowflake_creds.PASSWORD,
        role="ACCOUNTADMIN",
        warehouse="COMPUTE_WH",
        database="HEALTHDB",
        schema="PUBLIC"
            ))

# %%
def scoring_query(a):
    query_sim = f"""

    WITH BASE AS (

        SELECT CASE_ID,
               COALESCE(HOSPITAL_CODE,0) AS HOSPITAL_CODE,
               COALESCE(HOSPITAL_TYPE_CODE,'None') AS HOSPITAL_TYPE_CODE,
               COALESCE(CITY_CODE_HOSPITAL,0) AS CITY_CODE_HOSPITAL,
               COALESCE(HOSPITAL_REGION_CODE,'None') AS HOSPITAL_REGION_CODE,
               COALESCE(AVAILABLE_EXTRA_ROOMS_IN_HOSPITAL,0) AS AVAILABLE_EXTRA_ROOMS_IN_HOSPITAL,
               COALESCE(DEPARTMENT,'None') AS DEPARTMENT,
               COALESCE(WARD_TYPE,'None') AS WARD_TYPE,
               COALESCE(WARD_FACILITY_CODE,'None') AS WARD_FACILITY_CODE,
               COALESCE(BED_GRADE,0) AS BED_GRADE,
               PATIENTID,
               COALESCE(CITY_CODE_PATIENT,0) AS CITY_CODE_PATIENT,
               COALESCE(TYPE_OF_ADMISSION,'None') AS TYPE_OF_ADMISSION,
               COALESCE(SEVERITY_OF_ILLNESS,'Minor') AS SEVERITY_OF_ILLNESS,
               COALESCE(VISITORS_WITH_PATIENT,0) AS VISITORS_WITH_PATIENT,
               COALESCE(AGE,'None') AS AGE,
               COALESCE(ADMISSION_DEPOSIT,0) AS ADMISSION_DEPOSIT,
               ADMISSION_DATE,
               DISCHARGE_DATE

        FROM HEALTHDB.PUBLIC.SIMULATION_DATA

    ),

    BASE_WITH_FEATURES AS (

        SELECT *,
                MONTHNAME(ADMISSION_DATE) AS ADMISSION_MONTH,
                DAYNAME(ADMISSION_DATE) AS ADMISSION_DAY,
                CONCAT(TYPE_OF_ADMISSION,'-',SEVERITY_OF_ILLNESS) AS ADMISSION_ILLNESS,
                CONCAT(SEVERITY_OF_ILLNESS,'-',BED_GRADE) AS ILLNESS_BEDGRADE,
                CONCAT(DEPARTMENT,'-',SEVERITY_OF_ILLNESS) AS DEPARTMENT_ILLNESS,
                DATEDIFF(day,ADMISSION_DATE,DISCHARGE_DATE) AS LOS
        FROM BASE 

    )    

    SELECT * FROM BASE_WITH_FEATURES WHERE ADMISSION_DATE = CURRENT_DATE+{a}-544
    """
    return query_sim

# %%
def check_n_create_model_features(df,feat_list):
    test = pd.DataFrame()
    for col in feat_list:
        if col in df.columns.tolist():
            test[col] = df[col]
        else:
            test[col] = 0
    
    return test

# %%
def insert_predictions_to_snowflake_table(data):
    import pandas
    import snowflake.connector
    from snowflake.connector.pandas_tools import pd_writer, write_pandas
    

    engine = create_engine(URL(
                account = "kbxyguy-yh77168",
        user= snowflake_creds.USER_NAME,
        password= snowflake_creds.PASSWORD,
        role="ACCOUNTADMIN",
        warehouse="COMPUTE_WH",
        database="HEALTHDB",
        schema="PUBLIC"
            ))

    # Creating the logging table if not exists already
    table = 'TEMP_LOS_PREDICTION_MODEL_LOGGING_TABLE_EMAIL_MONITORED'
    
    # Inserting the data to snowflake logging table
    data.to_sql(table, engine, index=False, if_exists='append', method=pd_writer)
    return 'Success'

# %%
def send_status_mail(mail_string):
    import mail_creds
    import smtplib
    from email.mime.multipart import MIMEMultipart
    from email.mime.text import MIMEText
    from email.mime.multipart import MIMEMultipart
    from email.mime.base import MIMEBase
    from email.mime.text import MIMEText
    from email.utils import formatdate
    from email import encoders
    
    subject = 'Patient LOS Prediction - STATUS MAIL'
    mail_content = mail_string

    username= mail_creds.MAIL_ID
    password= mail_creds.APP_PASSWORD
    send_from = mail_creds.MAIL_ID
    send_to = mail_creds.MAIL_ID
    Cc = ''
    msg = MIMEMultipart()
    msg['From'] = send_from
    msg['To'] = send_to
    msg['Cc'] = Cc
    msg['Date'] = formatdate(localtime = True)
    msg['Subject'] = subject
    msg.attach(MIMEText(mail_content, 'plain'))
    smtp = smtplib.SMTP('smtp.gmail.com',587)
    smtp.ehlo()
    smtp.starttls()
    smtp.login(username,password)
    smtp.sendmail(send_from, send_to.split(',') + msg['Cc'].split(','), msg.as_string())
    smtp.quit()

# %%
def LOS_MODEL_DEPLOYMENT_SIM(x):
    try:
        import pickle
        import pandas as pd
        import numpy as np
        import sqlalchemy
        import snowflake.connector
        from sqlalchemy import create_engine

        import xgboost as xgb
        from datetime import datetime, timedelta
        import time  
        import pytz    
        tz_NY = pytz.timezone('America/Indianapolis')

        import warnings
        warnings.filterwarnings('ignore')   
        
        import snowflake_creds
        import LOS_Preprocessing
        from LOS_Preprocessing import preprocess_data
        
        # Creating the connection engine (way 1)
        engine = create_engine(URL(
                account = "kbxyguy-yh77168",
        user= snowflake_creds.USER_NAME,
        password= snowflake_creds.PASSWORD,
        role="ACCOUNTADMIN",
        warehouse="COMPUTE_WH",
        database="HEALTHDB",
        schema="PUBLIC"
            ))
        
        mail_list = []
        
        with engine.connect() as conn:
    
            # Loading the scoring data
#             print(scoring_query(x))
            score_data = pd.DataFrame(pd.read_sql(scoring_query(x),conn))
            score_data.columns = [col.upper() for col in score_data.columns.tolist()]
            print(score_data['ADMISSION_DATE'].max())
            mail_list.append('STEP-1: Loading Data complete')

            # Applying the preprocessing steps
            score_data_processed = LOS_Preprocessing.preprocess_data(score_data)
            mail_list.append('STEP-2: Applying the Preprocessing Steps complete')

            # Applying feature selection
            final_feats = pd.read_pickle('MODEL_FEATS.pkl')
            score_data_final = check_n_create_model_features(score_data_processed,final_feats)
            mail_list.append('STEP-3: Applying the Feature Selection Steps complete')

            # Getting the predictions
            model = xgboost.XGBRegressor()
            model.load_model('MODEL_XGB.model')
            score_data_final['PREDICTED_LOS'] = np.ceil(model.predict(score_data_final.drop('LOS',axis=1)))
            mail_list.append('STEP-4: Getting the Predictions complete')

            # Writing the dataframe to snowflake as a table
            score_data_final = score_data_final.reset_index()
            score_data_table = pd.merge(score_data,score_data_final,on='CASE_ID',how='left')
            status = insert_predictions_to_snowflake_table(score_data_table)
            mail_list.append('STEP-5: Writing the data to snowflake complete')
            
            # Creating the mail body
            mail_string = ",\n ".join(map(str, mail_list))
            send_status_mail(mail_string)
            print('Success')
    
    except Exception as e:
        
        mail_content = 'Schedule is failed'
        send_status_mail(mail_content)
        print('Failed')
        print(e)

# %%
#LOS_MODEL_DEPLOYMENT_SIM(1)

# %%
# Scheduling the notebook (for live scoring simulation)

import time
from datetime import datetime    
import pytz    
tz_NY = pytz.timezone('America/Indianapolis')   
 

# scheduled hours in 24-hour format
#hours_list = ["10:10","17:17"]
 
for i in range(1,31):
#     tz_NY = pytz.timezone('Asia/Kolkata')   
#     now = datetime.now(tz_NY)  # gets current datetime

#     hour = str(now.hour) # gets current hour
#     minute = str(now.minute) # gets current minute
#     current_time = f"{hour}:{minute}" # combines current hour and minute

#     # checks if current time is in the hours list
#     if current_time in hours_list:
#         LOS_MODEL_DEPLOYMENT()
    
    # Run the scoring script
    LOS_MODEL_DEPLOYMENT_SIM(i)
    
    #time.sleep(60) # waits a minute until it repeats
# Out:
# 2022-12-01
# Success
# 2022-12-02
# Success
# 2022-12-03
# Success
# 2022-12-04
# Success
# 2022-12-05
# Success
# 2022-12-06
# Success
# 2022-12-07
# Success
# 2022-12-08
# Success
# 2022-12-09
# Success
# 2022-12-10
# Success
# 2022-12-11
# Success
# 2022-12-12
# Success
# 2022-12-13
# Success
# 2022-12-14
# Success
# 2022-12-15
# Success
# 2022-12-16
# Success
# 2022-12-17
# Success
# 2022-12-18
# Success
# 2022-12-19
# Success
# 2022-12-20
# Success
# 2022-12-21
# Success
# 2022-12-22
# Success
# 2022-12-23
# Success
# 2022-12-24
# Success
# 2022-12-25
# Success
# 2022-12-26
# Success
# 2022-12-27
# Success
# 2022-12-28
# Success
# 2022-12-29
# Success
# 2022-12-30
# Success
